# %%
import pandas as pd

# %%
df=pd.read_csv("taxonomy.csv.xls")

# %%
df
# Out:
#       taxonomy_id                            name  parent_id  \
# 0             101                       Emergency        NaN
# 1          101-01               Disaster Response        101
# 2          101-02                  Emergency Cash        101
# 3       101-02-01               Help Pay for Food     101-02
# 4       101-02-02         Help Pay for Healthcare     101-02
# 5       101-02-03            Help Pay for Housing     101-02
# 6       101-02-04                Help Pay for Gas     101-02
# 7       101-02-05             Help Pay for School     101-02
# 8       101-02-06          Help Pay for Utilities     101-02
# 9          101-03                  Emergency Food        101
# 10         101-04               Emergency Shelter        101
# 11         101-05       Help Find Missing Persons        101
# 12         101-06                Immediate Safety        101
# 13      101-06-01            Help Escape Violence     101-06
# ...

# %%
df[df["parent_id"]== "111"]
# Out:
#     taxonomy_id                          name parent_id parent_name
# 274      111-01          Advocacy & Legal Aid       111       Legal
# 286      111-02                     Mediation       111       Legal
# 287      111-03                        Notary       111       Legal
# 288      111-04                Representation       111       Legal
# 289      111-05  Translation & Interpretation       111       Legal

# %%
df.loc[df["parent_id"]== "111"]
# Out:
#     taxonomy_id                          name parent_id parent_name
# 274      111-01          Advocacy & Legal Aid       111       Legal
# 286      111-02                     Mediation       111       Legal
# 287      111-03                        Notary       111       Legal
# 288      111-04                Representation       111       Legal
# 289      111-05  Translation & Interpretation       111       Legal

# %%
df[df["parent_id"]== "111"].count()
# Out:
# taxonomy_id    5
# name           5
# parent_id      5
# parent_name    5
# dtype: int64

# %%
df.loc[df["parent_id"]== "111"].count()
# Out:
# taxonomy_id    5
# name           5
# parent_id      5
# parent_name    5
# dtype: int64

# %%
df["parent_id"][df["parent_id"]== "111"].count()
# Out:
# 5

# %%
df.drop("taxonomy_id", axis=1).head()
# Out:
#                       name parent_id     parent_name
# 0                Emergency       NaN             NaN
# 1        Disaster Response       101       Emergency
# 2           Emergency Cash       101       Emergency
# 3        Help Pay for Food    101-02  Emergency Cash
# 4  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df.drop("taxonomy_id", axis=1, inplace= True)

# %%
df.head()
# Out:
#                       name parent_id     parent_name
# 0                Emergency       NaN             NaN
# 1        Disaster Response       101       Emergency
# 2           Emergency Cash       101       Emergency
# 3        Help Pay for Food    101-02  Emergency Cash
# 4  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df.reset_index(inplace=False)
# Out:
#      level_0  index                            name  parent_id  \
# 0          0      0                       Emergency        NaN
# 1          1      1               Disaster Response        101
# 2          2      2                  Emergency Cash        101
# 3          3      3               Help Pay for Food     101-02
# 4          4      4         Help Pay for Healthcare     101-02
# 5          5      5            Help Pay for Housing     101-02
# 6          6      6                Help Pay for Gas     101-02
# 7          7      7             Help Pay for School     101-02
# 8          8      8          Help Pay for Utilities     101-02
# 9          9      9                  Emergency Food        101
# 10        10     10               Emergency Shelter        101
# 11        11     11       Help Find Missing Persons        101
# 12        12     12                Immediate Safety        101
# 13        13     13            Help Escape Violence     101-06
# ...

# %%
df.drop("index", axis=1)
# Out:
#                                name  parent_id                 parent_name
# 0                         Emergency        NaN                         NaN
# 1                 Disaster Response        101                   Emergency
# 2                    Emergency Cash        101                   Emergency
# 3                 Help Pay for Food     101-02              Emergency Cash
# 4           Help Pay for Healthcare     101-02              Emergency Cash
# 5              Help Pay for Housing     101-02              Emergency Cash
# 6                  Help Pay for Gas     101-02              Emergency Cash
# 7               Help Pay for School     101-02              Emergency Cash
# 8            Help Pay for Utilities     101-02              Emergency Cash
# 9                    Emergency Food        101                   Emergency
# 10                Emergency Shelter        101                   Emergency
# ...

# %%
df.columns
# Out:
# Index(['index', 'name', 'parent_id', 'parent_name'], dtype='object')

# %%
df.loc['parent_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [parent_id] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-f058d918b700> in <module>()
# ----> 1 df.loc['parent_id']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
# ...

# %%
df= pd.read_csv("new populetion data.csv")

# %%
df.columns=df.iloc[0]

# %%
df.drop(0, axis=1, inplace=True)
df.drop(0, axis=0, inplace=True)

# %%
df.head()
# Out:
# 0             Division     Capital        Established Area (km2)[216]  \
# 1     Barisal Division     Barisal     1 January 1993           13225
# 2  Chittagong Division  Chittagong     1 January 1829           33909
# 3       Dhaka Division       Dhaka     1 January 1829           20594
# 4      Khulna Division      Khulna     1 October 1960           22284
# 5  Mymensingh Division  Mymensingh  14 September 2015           10584
#
# 0 2021 Population (projected)[217] Density2021
# 1                          9713000         734
# 2                         34747000        1025
# 3                         42607000        2069
# 4                         18217000         817
# 5                         13457000        1271

# %%
df.iloc[:,1]
# Out:
# 1       Barisal
# 2    Chittagong
# 3         Dhaka
# 4        Khulna
# 5    Mymensingh
# 6      Rajshahi
# 7       Rangpur
# 8        Sylhet
# Name: Capital, dtype: object

# %%
df.loc[:,"Division"]
# Out:
# 1       Barisal Division
# 2    Chittagong Division
# 3         Dhaka Division
# 4        Khulna Division
# 5    Mymensingh Division
# 6      Rajshahi Division
# 7       Rangpur Division
# 8        Sylhet Division
# Name: Division, dtype: object

# %%
df.loc[3,"Division"]
# Out:
# 'Dhaka Division'

# %%
df.loc[df["Division"]=="Dhaka Division", ["Capital", "Established"]]
# Out:
# 0 Capital     Established
# 3   Dhaka  1 January 1829

# %%
df.loc[df["Capital"]=="Dhaka", ["Established"]]
# Out:
# 0     Established
# 3  1 January 1829

# %%
df=pd.read_csv("taxonomy.csv.xls")

# %%
df.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df.dropna()
# Out:
#       taxonomy_id                            name  parent_id  \
# 1          101-01               Disaster Response        101
# 2          101-02                  Emergency Cash        101
# 3       101-02-01               Help Pay for Food     101-02
# 4       101-02-02         Help Pay for Healthcare     101-02
# 5       101-02-03            Help Pay for Housing     101-02
# 6       101-02-04                Help Pay for Gas     101-02
# 7       101-02-05             Help Pay for School     101-02
# 8       101-02-06          Help Pay for Utilities     101-02
# 9          101-03                  Emergency Food        101
# 10         101-04               Emergency Shelter        101
# 11         101-05       Help Find Missing Persons        101
# 12         101-06                Immediate Safety        101
# 13      101-06-01            Help Escape Violence     101-06
# 14      101-06-02                    Safe Housing     101-06
# ...

# %%
df.dropna(axis=1)
# Out:
#       taxonomy_id                            name
# 0             101                       Emergency
# 1          101-01               Disaster Response
# 2          101-02                  Emergency Cash
# 3       101-02-01               Help Pay for Food
# 4       101-02-02         Help Pay for Healthcare
# 5       101-02-03            Help Pay for Housing
# 6       101-02-04                Help Pay for Gas
# 7       101-02-05             Help Pay for School
# 8       101-02-06          Help Pay for Utilities
# 9          101-03                  Emergency Food
# 10         101-04               Emergency Shelter
# 11         101-05       Help Find Missing Persons
# 12         101-06                Immediate Safety
# 13      101-06-01            Help Escape Violence
# 14      101-06-02                    Safe Housing
# 15         101-07  Psychiatric Emergency Services
# 16            102                            Food
# 17         102-01               Community Gardens
# ...

# %%
df
# Out:
#       taxonomy_id                            name  parent_id  \
# 0             101                       Emergency        NaN
# 1          101-01               Disaster Response        101
# 2          101-02                  Emergency Cash        101
# 3       101-02-01               Help Pay for Food     101-02
# 4       101-02-02         Help Pay for Healthcare     101-02
# 5       101-02-03            Help Pay for Housing     101-02
# 6       101-02-04                Help Pay for Gas     101-02
# 7       101-02-05             Help Pay for School     101-02
# 8       101-02-06          Help Pay for Utilities     101-02
# 9          101-03                  Emergency Food        101
# 10         101-04               Emergency Shelter        101
# 11         101-05       Help Find Missing Persons        101
# 12         101-06                Immediate Safety        101
# 13      101-06-01            Help Escape Violence     101-06
# ...

# %%
df.fillna("nahid")
# Out:
#       taxonomy_id                            name  parent_id  \
# 0             101                       Emergency      nahid
# 1          101-01               Disaster Response        101
# 2          101-02                  Emergency Cash        101
# 3       101-02-01               Help Pay for Food     101-02
# 4       101-02-02         Help Pay for Healthcare     101-02
# 5       101-02-03            Help Pay for Housing     101-02
# 6       101-02-04                Help Pay for Gas     101-02
# 7       101-02-05             Help Pay for School     101-02
# 8       101-02-06          Help Pay for Utilities     101-02
# 9          101-03                  Emergency Food        101
# 10         101-04               Emergency Shelter        101
# 11         101-05       Help Find Missing Persons        101
# 12         101-06                Immediate Safety        101
# 13      101-06-01            Help Escape Violence     101-06
# ...

# %%
df
# Out:
#       taxonomy_id                            name  parent_id  \
# 0             101                       Emergency        NaN
# 1          101-01               Disaster Response        101
# 2          101-02                  Emergency Cash        101
# 3       101-02-01               Help Pay for Food     101-02
# 4       101-02-02         Help Pay for Healthcare     101-02
# 5       101-02-03            Help Pay for Housing     101-02
# 6       101-02-04                Help Pay for Gas     101-02
# 7       101-02-05             Help Pay for School     101-02
# 8       101-02-06          Help Pay for Utilities     101-02
# 9          101-03                  Emergency Food        101
# 10         101-04               Emergency Shelter        101
# 11         101-05       Help Find Missing Persons        101
# 12         101-06                Immediate Safety        101
# 13      101-06-01            Help Escape Violence     101-06
# ...

# %%
df.groupby("parent_name").count()
# Out:
#                             taxonomy_id  name  parent_id
# parent_name
# Addiction & Recovery                  5     5          5
# Adoption & Foster Care                8     8          8
# Advocacy & Legal Aid                  7     7          7
# Baby Supplies                         2     2          2
# Care                                  7     7          7
# Checkup & Test                        6     6          6
# Childcare                             2     2          2
# Clothing                              4     4          4
# Daytime Care                          7     7          7
# Education                             6     6          6
# Emergency                             7     7          7
# Emergency Cash                        6     6          6
# End-of-Life Care                      8     8          8
# Financial Assistance                  7     7          7
# Financial Education                   7     7          7
# ...
