# %%
import pandas as pd

# %%
df=pd.read_csv("titanic_data.csv")

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
object_dtypes= df[df.dtypes[df.dtypes=="object"].index]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=="int64"
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes=="int64"].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="int64"].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# 5              6         0       3      0      0
# 6              7         0       1      0      0
# 7              8         0       3      3      1
# 8              9         1       3      0      2
# 9             10         1       2      1      0
# 10            11         1       3      1      1
# 11            12         1       1      0      0
# 12            13         0       3      0      0
# 13            14         0       3      1      5
# 14            15         0       3      0      0
# 15            16         1       2      0      0
# 16            17         0       3      4      1
# 17            18         1       2      0      0
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes== "float64"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes== "float64" ].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
df[df.dtypes[df.dtypes== "float64" ].index]
# Out:
#       Age      Fare
# 0    22.0    7.2500
# 1    38.0   71.2833
# 2    26.0    7.9250
# 3    35.0   53.1000
# 4    35.0    8.0500
# 5     NaN    8.4583
# 6    54.0   51.8625
# 7     2.0   21.0750
# 8    27.0   11.1333
# 9    14.0   30.0708
# 10    4.0   16.7000
# 11   58.0   26.5500
# 12   20.0    8.0500
# 13   39.0   31.2750
# 14   14.0    7.8542
# 15   55.0   16.0000
# 16    2.0   29.1250
# 17    NaN   13.0000
# 18   31.0   18.0000
# 19    NaN    7.2250
# 20   35.0   26.0000
# 21   34.0   13.0000
# 22   15.0    8.0292
# 23   28.0   35.5000
# 24    8.0   21.0750
# 25   38.0   31.3875
# 26    NaN    7.2250
# 27   19.0  263.0000
# 28    NaN    7.8792
# 29    NaN    7.8958
# ..    ...       ...
# 861  21.0   11.5000
# 862  48.0   25.9292
# 863   NaN   69.5500
# 864  24.0   13.0000
# 865  42.0   13.0000
# 866  27.0   13.8583
# 867  31.0   50.4958
# 868   NaN    9.5000
# 869   4.0   11.1333
# 870  26.0    7.8958
# 871  47.0   52.5542
# 872  33.0    5.0000
# 873  47.0    9.0000
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# 5              6         0
# 6              7         0
# 7              8         0
# 8              9         1
# 9             10         1
# 10            11         1
# 11            12         1
# 12            13         0
# 13            14         0
# 14            15         0
# 15            16         1
# 16            17         0
# 17            18         1
# 18            19         0
# 19            20         1
# 20            21         0
# 21            22         1
# 22            23         1
# 23            24         1
# 24            25         0
# 25            26         1
# 26            27         0
# 27            28         0
# 28            29         1
# 29            30         0
# ..           ...       ...
# 861          862         0
# 862          863         1
# ...

# %%
df[['PassengerId', 'Survived']][10:17:2]
# Out:
#     PassengerId  Survived
# 10           11         1
# 12           13         0
# 14           15         0
# 16           17         0

# %%
import numpy as np

# %%
df["Survived_b"] = np.where(df["Survived_c"] == "yes" , 1, 0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Survived_c  Survived_b
# 0      0         A/5 21171   7.2500   NaN        S         No           0
# 1      0          PC 17599  71.2833   C85        C        yes           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        yes           1
# ...

# %%
pd.Categorical(df["Embarked"])
# Out:
# [S, C, S, S, S, ..., S, S, S, C, Q]
# Length: 891
# Categories (3, object): [C, Q, S]

# %%
conditions =[
    (df["Age"] >= 20) & (df["Age"] <= 40),
    (df["Age"] >= 41) & (df["Age"] <= 60),
    (df["Age"] >= 61) & (df["Age"] <= 80)
]

# %%
control= ["Young","Adult","Old"]

# %%
df["Age_c"]= np.select(conditions,control, default="Children")

# %%
pd.Categorical(df["Age_c"])
# Out:
# [Young, Young, Young, Young, Young, ..., Young, Children, Children, Young, Young]
# Length: 891
# Categories (4, object): [Adult, Children, Old, Young]

# %%
df["Age_c"].unique()
# Out:
# array(['Young', 'Children', 'Adult', 'Old'], dtype=object)

# %%
df["Age"][df["Age"]>18]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 6      54.0
# 8      27.0
# 11     58.0
# 12     20.0
# 13     39.0
# 15     55.0
# 18     31.0
# 20     35.0
# 21     34.0
# 23     28.0
# 25     38.0
# 27     19.0
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 37     21.0
# 40     40.0
# 41     27.0
# 44     19.0
# 51     21.0
# 52     49.0
# 53     29.0
# 54     65.0
# 56     21.0
#        ...
# 851    74.0
# 854    44.0
# 856    45.0
# 857    51.0
# 858    24.0
# 860    41.0
# 861    21.0
# 862    48.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 876    20.0
# 877    19.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 575, dtype: float64

# %%
len(df)- len(df[df["Age"]>18])
# Out:
# 316

# %%
df[(df["Age"]>18) & (df["Sex"]== "male")]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 33            34         0       2                 Wheadon, Mr. Edward H
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ...

# %%
df.loc[1:30, "Age"]
# Out:
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# 20    35.0
# 21    34.0
# 22    15.0
# 23    28.0
# 24     8.0
# 25    38.0
# 26     NaN
# 27    19.0
# 28     NaN
# 29     NaN
# 30    40.0
# Name: Age, dtype: float64

# %%
df.loc[df["Age"]<20]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 24            25         0       3
# 27            28         0       1
# 38            39         0       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 49            50         0       3
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 67            68         0       3
# 68            69         1       3
# 71            72         0       3
# 78            79         1       2
# 84            85         1       2
# 86            87         0       3
# 111          112         0       3
# 114          115         0       3
# ...

# %%
df["Age"][df["Age"]<20]
# Out:
# 7       2.00
# 9      14.00
# 10      4.00
# 14     14.00
# 16      2.00
# 22     15.00
# 24      8.00
# 27     19.00
# 38     18.00
# 39     14.00
# 43      3.00
# 44     19.00
# 49     18.00
# 50      7.00
# 58      5.00
# 59     11.00
# 63      4.00
# 67     19.00
# 68     17.00
# 71     16.00
# 78      0.83
# 84     17.00
# 86     16.00
# 111    14.50
# 114    17.00
# 119     2.00
# 125    12.00
# 136    19.00
# 138    16.00
# 143    19.00
#        ...
# 757    18.00
# 764    16.00
# 775    18.00
# 777     5.00
# 780    13.00
# 781    17.00
# 786    18.00
# 787     8.00
# 788     1.00
# 791    16.00
# 802    11.00
# 803     0.42
# 807    18.00
# 813     6.00
# 819    10.00
# 824     2.00
# 827     1.00
# 830    15.00
# 831     0.83
# 834    18.00
# 841    16.00
# 844    17.00
# 850     4.00
# 852     9.00
# 853    16.00
# 855    18.00
# 869     4.00
# 875    15.00
# 877    19.00
# 887    19.00
# Name: Age, Length: 164, dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Survived_c  Survived_b  \
# 0      0         A/5 21171   7.2500   NaN        S         No           0
# 1      0          PC 17599  71.2833   C85        C        yes           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        yes           1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Survived_b
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.383838
# std      0.806057   49.693429    0.486592
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    0.000000
# 75%      0.000000   31.000000    1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Survived_c     891 non-null object
# Survived_b     891 non-null int32
# Age_c          891 non-null object
# dtypes: float64(2), int32(1), int64(5), object(7)
# memory usage: 101.0+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived_c',
#        'Survived_b', 'Age_c'],
#       dtype='object')

# %%
df["Name"][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
len(df["Name"][2:11])
# Out:
# 9

# %%
l=["a","b","c"]

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
df["Name"][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
pd.Series(df["Name"][2:7], index=[1,2,3,4,5])
# Out:
# 1                                             NaN
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Survived_c  Survived_b  \
# 0      0         A/5 21171   7.2500   NaN        S         No           0
# 1      0          PC 17599  71.2833   C85        C        yes           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        yes           1
# ...

# %%
df.drop('Survived_c',axis=1,inplace= True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived_b  Age_c
# 0           0  Young
# 1           1  Young
# 2           1  Young
# ...

# %%
df.set_index("Name", inplace= True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# McCarthy, Mr. Timothy J                                    0       1    male
# Palsson, Master. Gosta Leonard                             0       3    male
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)          1       3  female
# Nasser, Mrs. Nicholas (Adele Achem)                        1       2  female
# Sandstrom, Miss. Marguerite Rut                            1       3  female
# ...

# %%
df.loc["Allen, Mr. William Henry"]
# Out:
# Survived           0
# Pclass             3
# Sex             male
# Age               35
# SibSp              0
# Parch              0
# Ticket        373450
# Fare            8.05
# Cabin            NaN
# Embarked           S
# Survived_b         0
# Age_c          Young
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.iloc[3]
# Out:
# Survived           1
# Pclass             1
# Sex           female
# Age               35
# SibSp              1
# Parch              0
# Ticket        113803
# Fare            53.1
# Cabin           C123
# Embarked           S
# Survived_b         1
# Age_c          Young
# Name: Futrelle, Mrs. Jacques Heath (Lily May Peel), dtype: object

# %%
df.head()
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index                                               Name  Survived  Pclass  \
# 0      0                            Braund, Mr. Owen Harris         0       3
# 1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2      2                             Heikkinen, Miss. Laina         1       3
# 3      3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4      4                           Allen, Mr. William Henry         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived_b  Age_c
# 0           0  Young
# ...

# %%
d= {"key1":[1,2,3,4],
    "key2":[3,2,1,4],
    "key3":[5,6,7,8]
   }

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     2     2     6
# 2     3     1     7
# 3     4     4     8

# %%
df=pd.read_csv("taxonomy.csv")

# %%
df.head()
# Out:
#               taxonomy_id,name,parent_id,parent_name
# 0                                    101,Emergency,,
# 1             101-01,Disaster Response,101,Emergency
# 2                101-02,Emergency Cash,101,Emergency
# 3  101-02-01,Help Pay for Food,101-02,Emergency Cash
# 4  101-02-02,Help Pay for Healthcare,101-02,Emerg...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df)
# Out:
# ['taxonomy_id,name,parent_id,parent_name']

# %%
df=pd.read_csv("taxonomy.exel")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-183-c95fc65f6a3b> in <module>()
# ----> 1 df=pd.read_csv("taxonomy.exel")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
df= pd.read_csv("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined
